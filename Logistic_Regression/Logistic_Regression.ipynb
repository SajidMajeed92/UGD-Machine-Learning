# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
train_test_split(X,y,test_size=0.1)
# Out:
# [    cgpa     iq
#  72   7.3  116.0
#  44   7.5   61.0
#  52   7.0  175.0
#  33   6.0  149.0
#  13   6.4  116.0
#  ..   ...    ...
#  29   7.0  112.0
#  93   6.8  112.0
#  96   4.4   42.0
#  24   4.7  121.0
#  60   6.9  139.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  66   6.9   96.0
#  9    5.1   66.0
#  4    5.8  142.0
#  17   3.3  183.0
#  7    5.0   63.0
#  21   7.1  151.0
#  79   6.5   90.0
#  68   4.0   75.0
#  49   5.4  135.0
#  5    7.1   48.0,
#  72    1
#  44    1
#  52    1
#  33    0
#  13    1
#       ..
#  29    1
#  93    1
#  96    0
#  24    0
#  60    1
#  Name: placement, Length: 90, dtype: int64,
#  66    1
#  9     0
#  4     0
#  17    0
#  7     0
#  21    1
#  79    1
#  68    0
#  49    0
#  5     1
#  Name: placement, dtype: int64]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
len(X_train)
# Out:
# 90

# %%
y_train
# Out:
# 59    0
# 77    1
# 87    1
# 22    0
# 67    0
#      ..
# 46    0
# 49    0
# 55    1
# 63    1
# 91    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 42   7.6   89.0
# 75   4.8  169.0
# 32   7.0  139.0
# 51   4.8  141.0
# 45   6.0   66.0
# 40   4.9  134.0
# 65   8.1  166.0
# 34   4.8  163.0
# 52   7.0  175.0
# 47   5.2  161.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-1.05381384, -0.2438817 ],
#        [ 1.16422277, -1.79915016],
#        [-0.25532066,  0.2578178 ],
#        [-0.96509238, -0.0432019 ],
#        [-0.87637091, -0.09337185],
#        [ 0.0995652 , -1.42287553],
#        [-0.52148505, -0.36930658],
#        [ 1.25294424,  0.2578178 ],
#        [-0.16659919,  1.11070695],
#        [ 1.3416657 ,  0.20764785],
#        [ 0.18828666, -0.21879673],
#        [ 0.54317252,  0.40832765],
#        [-1.1425353 , -1.74898021],
#        [ 0.45445106,  0.9601971 ],
#        [-0.16659919,  0.50866755],
#        [ 1.3416657 , -1.52321543],
#        [ 0.98677984, -1.84932011],
#        [-1.23125677,  0.60900745],
#        [ 1.87399449,  0.68426238],
#        [-0.25532066,  0.53375253],
#        [-0.96509238,  0.73443233],
#        [ 0.89805838,  1.93851113],
#        [-0.96509238,  1.8632562 ],
#        [ 0.27700813, -0.46964648],
#        [ 0.72061545,  0.48358258],
#        [ 1.16422277, -0.1435418 ],
#        [ 0.27700813,  0.13239292],
#        [-0.07787773, -0.39439155],
#        [ 0.54317252, -0.0432019 ],
#        [ 2.22888035, -0.0432019 ],
#        [-0.78764945,  0.1574779 ],
#        [-0.78764945,  1.3615567 ],
#        [-0.52148505, -0.19371175],
#        [ 0.36572959, -0.1435418 ],
#        [-2.20719288,  2.79140028],
#        [-1.49742116,  1.9635961 ],
#        [ 0.63189399,  0.80968725],
#        [ 0.98677984,  0.73443233],
#        [-0.87637091, -1.47304548],
#        [-2.38463581,  1.53715153],
#        [ 1.16422277,  0.38324267],
#        [ 2.05143742,  1.1608769 ],
#        [ 0.80933692,  0.43341262],
#        [ 0.36572959,  0.48358258],
#        [ 0.01084373,  0.057138  ],
#        [ 0.89805838, -0.2438817 ],
#        [ 0.01084373, -1.92457503],
#        [ 1.78527303, -1.07168588],
#        [ 1.16422277, -0.89609105],
#        [ 0.0995652 , -1.02151593],
#        [ 0.72061545, -0.2438817 ],
#        [-0.61020652, -0.01811693],
#        [ 0.63189399,  1.51206655],
#        [-1.85230702, -0.31913663],
#        [-0.87637091, -0.77066618],
#        [ 0.72061545,  0.03205302],
#        [ 0.45445106, -2.12525483],
#        [ 0.80933692, -0.6452413 ],
#        [-0.96509238, -1.52321543],
#        [ 1.43038717,  0.1574779 ],
#        [ 0.45445106,  0.20764785],
#        [-1.1425353 , -0.01811693],
#        [-1.76358556, -0.5449014 ],
#        [-1.1425353 , -0.87100608],
#        [ 0.01084373, -0.49473145],
#        [ 0.01084373,  0.68426238],
#        [-0.96509238,  0.83477223],
#        [-1.4086997 ,  0.68426238],
#        [-0.25532066,  1.18596188],
#        [ 0.45445106, -0.79575115],
#        [ 0.0995652 ,  0.8598572 ],
#        [ 0.80933692,  0.40832765],
#        [ 0.89805838, -1.44796051],
#        [ 0.72061545, -0.79575115],
#        [-1.76358556, -1.17202578],
#        [-0.25532066,  0.4584976 ],
#        [-0.69892798,  0.2578178 ],
#        [ 0.0995652 ,  0.2578178 ],
#        [-0.78764945, -1.39779056],
#        [-0.52148505,  0.43341262],
#        [-0.69892798, -0.79575115],
#        [-0.69892798, -0.29405165],
#        [-1.4086997 , -1.99982996],
#        [-0.69892798,  2.56563551],
#        [ 0.0995652 , -0.46964648],
#        [-0.61020652, -0.19371175],
#        [-0.52148505,  0.33307272],
#        [ 1.6078301 , -0.19371175],
#        [ 0.27700813,  0.1574779 ],
#        [ 1.3416657 ,  0.91002715]])

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 1.43038717, -0.82083613],
#        [-1.05381384,  1.18596188],
#        [ 0.89805838,  0.43341262],
#        [-1.05381384,  0.48358258],
#        [ 0.01084373, -1.39779056],
#        [-0.96509238,  0.30798775],
#        [ 1.87399449,  1.11070695],
#        [-1.05381384,  1.03545203],
#        [ 0.89805838,  1.33647173],
#        [-0.69892798,  0.98528208]])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 0, 1, 0], dtype=int64)

# %%
y_test
# Out:
# 42    1
# 75    0
# 32    1
# 51    0
# 45    1
# 40    0
# 65    1
# 34    0
# 52    1
# 47    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
